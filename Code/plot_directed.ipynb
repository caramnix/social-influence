# %% [markdown]
# # Directed Graph
#
# Draw a graph with directed edges using a colormap and different node sizes.
#
# Edges have different colors and alphas (opacity). Drawn using matplotlib.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx

seed = 13648  # Seed random number generators for reproducibility
G = nx.random_k_out_graph(10, 3, 0.5, seed=seed)
pos = nx.spring_layout(G, seed=seed)

node_sizes = [3 + 10 * i for i in range(len(G))]
M = G.number_of_edges()
edge_colors = range(2, M + 2)
edge_alphas = [(5 + i) / (M + 4) for i in range(M)]
cmap = plt.cm.plasma

nodes = nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color="indigo")
edges = nx.draw_networkx_edges(
    G,
    pos,
    node_size=node_sizes,
    arrowstyle="->",
    arrowsize=10,
    edge_color=edge_colors,
    edge_cmap=cmap,
    width=2,
)
# set alpha value for each edge
for i in range(M):
    edges[i].set_alpha(edge_alphas[i])

    
    
pc = mpl.collections.PatchCollection(edges, cmap=cmap)
pc.set_array(edge_colors)

ax = plt.gca()
ax.set_axis_off()
plt.colorbar(pc, ax=ax)
plt.show()
# Out:
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_8655/276749726.py:16: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   edges = nx.draw_networkx_edges(

# %%
print(G)
# Out:
# MultiDiGraph with 10 nodes and 30 edges

# %%
path_dij= "/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/Social Influence/Data/Twitter/116/House/house_116_tweets/dijkstra_mat_Twitter_House_116.csv"

# %%
import networkx as nx

G = nx.Graph()
G.add_nodes_from([1:

    (1, {"color": "orange"}),

    (2, {"color": "green"}),
    
    (3, {"color": "pink"}), 
    
    (4, {"color": "yellow"}), 
     
    (5, {"color": "purple"}), 

])

# %%
# node 1 
['OMAR', 'D', 'Rep. Omar, Ilhan [D-MN-5]', '2414']
['TLAIB', 'D', 'Rep. Tlaib, Rashida [D-MI-13]', '2410']
['PRESSLEY', 'D', 'Rep. Pressley, Ayanna [D-MA-7]', '2405']
['JAYAPAL', 'D', 'Rep. Jayapal, Pramila [D-WA-7]', '2354']
['POCAN', 'D', 'Rep. Pocan, Mark [D-WI-2]', '2171']
['OCASIO-CORTEZ', 'D', 'Rep. Ocasio-Cortez, Alexandria [D-NY-14]', '2427']

#node 2
['PRESSLEY', 'D', 'Rep. Pressley, Ayanna [D-MA-7]', '2405']
['TLAIB', 'D', 'Rep. Tlaib, Rashida [D-MI-13]', '2410']
['OMAR', 'D', 'Rep. Omar, Ilhan [D-MN-5]', '2414']
['OCASIO-CORTEZ', 'D', 'Rep. Ocasio-Cortez, Alexandria [D-NY-14]', '2427']
['JAYAPAL', 'D', 'Rep. Jayapal, Pramila [D-WA-7]', '2354']
['GARCIA', 'D', 'Rep. Garcia, Jesus G. "Chuy" [D-IL-4]', '2397']

#node 3
['TLAIB', 'D', 'Rep. Tlaib, Rashida [D-MI-13]', '2410']
['OMAR', 'D', 'Rep. Omar, Ilhan [D-MN-5]', '2414']
['PRESSLEY', 'D', 'Rep. Pressley, Ayanna [D-MA-7]', '2405']
['JAYAPAL', 'D', 'Rep. Jayapal, Pramila [D-WA-7]', '2354']
['POCAN', 'D', 'Rep. Pocan, Mark [D-WI-2]', '2171']
['OCASIO-CORTEZ', 'D', 'Rep. Ocasio-Cortez, Alexandria [D-NY-14]', '2427']

#node 4 
['OCASIO-CORTEZ', 'D', 'Rep. Ocasio-Cortez, Alexandria [D-NY-14]', '2427']
['TLAIB', 'D', 'Rep. Tlaib, Rashida [D-MI-13]', '2410']
['OMAR', 'D', 'Rep. Omar, Ilhan [D-MN-5]', '2414']
['PRESSLEY', 'D', 'Rep. Pressley, Ayanna [D-MA-7]', '2405']
['LONG', 'R', 'Rep. Long, Billy [R-MO-7]', '2033']
['MALONEY', 'D', 'Rep. Maloney, Carolyn B. [D-NY-12]', '729']

# node 5 
['JAYAPAL', 'D', 'Rep. Jayapal, Pramila [D-WA-7]', '2354']

#node 6 
['POCAN', 'D', 'Rep. Pocan, Mark [D-WI-2]', '2171']

#node 7 
['LONG', 'R', 'Rep. Long, Billy [R-MO-7]', '2033']

#nde 8 
['MALONEY', 'D', 'Rep. Maloney, Carolyn B. [D-NY-12]', '729']

#node 9 
['GARCIA', 'D', 'Rep. Garcia, Jesus G. "Chuy" [D-IL-4]', '2397']

# %%
DG = nx.DiGraph()

DG.add_nodes_from([1,2, 3, 4, 5, 6, 7,8, 9])

DG.add_edges_from([(1, 3), (1, 2), (1,4), (1,5), (1,6) ], color="orange")

DG.add_edges_from([(2, 1), (2, 3), (2,4), (2,5), (2,9) ], color="green")

DG.add_edges_from([(3, 1), (3, 2), (3,4), (3,5), (3,6) ], color="blue")

DG.add_edges_from([(4, 1), (4, 2), (4,3), (4,7), (4,8) ], color="yellow")


#DG.add_weighted_edges_from([(1, 2, 1), (3, 1, 1)], color ="red")

# %%
import matplotlib.pyplot as plt
seed = 11
#plt.figure(figsize=(8,8))


pos = nx.circular_layout(DG)
edges = DG.edges()
colors = [DG[u][v]['color'] for u,v in edges]

node_colors=['orange', 'green', 'blue', 'yellow', 'grey', 'grey', 'grey', 'grey', 'grey']

#labels= ["1", "2", "3", "4", "5", "6", "7", "8"]


labeldict ={1: "OMAR", 2: "PRESSLEY", 3: "TLAIB", 4: "OCASIO-CORTEZ", 5: "JAYAPAL", 6 : 'POCAN', 7: "LONG", 8 : "MALONEY", 9: "GARCIA"}
nx.draw(DG, pos, node_color= node_colors, edge_color=colors) #, labels=labeldict,  with_labels = True, connectionstyle='arc3')
    
x,y= pos[1]
plt.text(x + .15 ,y -.03 ,s='OMAR', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')


x,y= pos[2]
plt.text(x + .2 ,y -.02 ,s='PRESSLEY', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[3]
plt.text(x ,y +.1 ,s='TLAIB', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[4]
plt.text(x-.3,y-.02 ,s='OCASIO-CORTEZ', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[5]
plt.text(x-.16,y-.02 ,s='JAYAPAL', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[6]
plt.text(x-.15,y-.03 ,s='POCAN', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[7]
plt.text(x,y-.15 ,s='LONG', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[8]
plt.text(x,y-.15 ,s='MALONEY', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[9]
plt.text(x,y-.15 ,s='GARCIA', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

    
plt.show()

#https://stackoverflow.com/questions/14547388/networkx-in-python-draw-node-attributes-as-labels-outside-the-node

# %%
import matplotlib.pyplot as plt
seed = 11
plt.figure(figsize=(10,8))

DG = nx.DiGraph()

DG.add_nodes_from([1,2, 3, 4, 5, 6, 7,8, 9])

DG.add_edges_from([(1, 3), (1, 2), (1,4), (1,5), (1,6) ], color="orange")

DG.add_edges_from([(2, 1), (2, 3), (2,4), (2,5), (2,9) ], color="lime")

DG.add_edges_from([(3, 1), (3, 2), (3,4), (3,5), (3,6) ], color="cyan")

DG.add_edges_from([(4, 1), (4, 2), (4,3), (4,7), (4,8) ], color="fuchsia")


pos = nx.circular_layout(DG)
edges = DG.edges()
colors = [DG[u][v]['color'] for u,v in edges]

node_colors=['orange', 'lime', 'cyan', 'fuchsia', 'grey', 'grey', 'grey', 'grey', 'grey']


labeldict ={1: "OMAR", 2: "PRESSLEY", 3: "TLAIB", 4: "OCASIO-CORTEZ", 5: "JAYAPAL", 6 : 'POCAN', 7: "LONG", 8 : "MALONEY", 9: "GARCIA"}
#nx.draw(DG, pos, node_color= node_colors, edge_color=colors) #, labels=labeldict,  with_labels = True, connectionstyle='arc3')

nx.draw_networkx_nodes(DG, pos, node_color=node_colors, node_shape='o', edgecolors="black")

nx.draw_networkx_edges(DG, pos, edgelist=edges, edge_color=colors, connectionstyle='arc3,rad=0.1') 

x,y= pos[1]
plt.text(x + .125 ,y -.022 ,s='OMAR', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')


x,y= pos[2]
plt.text(x + .17 ,y -.02 ,s='PRESSLEY', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[3]
plt.text(x ,y +.1 ,s='TLAIB', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[4]
plt.text(x-.23,y-.02 ,s='OCASIO-CORTEZ', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[5]
plt.text(x-.13,y-.02 ,s='JAYAPAL', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[6]
plt.text(x-.13,y-.02 ,s='POCAN', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[7]
plt.text(x,y-.13 ,s='LONG', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[8]
plt.text(x,y-.13 ,s='MALONEY', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')

x,y= pos[9]
plt.text(x,y-.13 ,s='GARCIA', bbox=dict(facecolor='none', edgecolor='none', alpha=0.5),horizontalalignment='center')


plt.box(False)
plt.savefig('squad_connections.png', dpi=1200)
#plt.show()

#https://stackoverflow.com/questions/14547388/networkx-in-python-draw-node-attributes-as-labels-outside-the-node
# Out:
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_8655/3378247399.py:30: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   nx.draw_networkx_edges(DG, pos, edgelist=edges, edge_color=colors, connectionstyle='arc3,rad=0.1')

# %%
edges
# Out:
# OutEdgeView([(1, 3), (1, 2), (1, 4), (1, 5), (1, 6), (2, 1), (2, 3), (2, 4), (2, 5), (2, 9), (3, 1), (3, 2), (3, 4), (3, 5), (3, 6), (4, 1), (4, 2), (4, 3), (4, 7), (4, 8)])

# %%
import networkx as nx

G = nx.Graph()
G.add_edge(1,2,color='r',weight=2)
G.add_edge(2,3,color='b',weight=4)
G.add_edge(3,4,color='g',weight=6)

pos = nx.circular_layout(G)

edges = G.edges()
colors = [G[u][v]['color'] for u,v in edges]
weights = [G[u][v]['weight'] for u,v in edges]

nx.draw(G, pos, edges=edges, edge_color=colors, width=weights)
